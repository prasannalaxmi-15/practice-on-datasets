# %%
import pandas as pd
import numpy as np

# %%
#-------------------series-------------------


s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
s.shape
# Out:
# (5,)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name="numbers"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %%
s[0]
# Out:
# 10

# %%
s[0:4]
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
s.iloc[2]
# Out:
# 30

# %%
s.iloc[1]
# Out:
# 20

# %%
s.loc[1:2]
# Out:
# 1    20
# 2    30
# Name: numbers, dtype: int64

# %%
index=["prasanna","spandana","haru","harshitha","ammu"]
index
# Out:
# ['prasanna', 'spandana', 'haru', 'harshitha', 'ammu']

# %%
s.index=index
s
# Out:
# prasanna     10
# spandana     20
# haru         30
# harshitha    40
# ammu         50
# Name: numbers, dtype: int64

# %%
s['prasanna']
# Out:
# 10

# %%
s.iloc[1]
# Out:
# 20

# %%
s.loc["prasanna"]
# Out:
# 10

# %%
s.loc["haru"]
# Out:
# 30

# %%
students_attendance={
    "prasanna":30,
    "harika":40,
    "harshitha":65,
    "spandana":85,
    "ammu":35,
    "teddy":45,
    "srivani":78
}

# %%
s2=pd.Series(students_attendance)

# %%
s2>50
# Out:
# prasanna     False
# harika       False
# harshitha     True
# spandana      True
# ammu         False
# teddy        False
# srivani       True
# dtype: bool

# %% [markdown]
# s2<50

# %%
s2<50
# Out:
# prasanna      True
# harika        True
# harshitha    False
# spandana     False
# ammu          True
# teddy         True
# srivani      False
# dtype: bool

# %%
s2[s2>50]
# Out:
# harshitha    65
# spandana     85
# srivani      78
# dtype: int64

# %%
s2[(s2 > 40) & (s2 < 80)]
# Out:
# harshitha    65
# teddy        45
# srivani      78
# dtype: int64

# %%
s2[~(s2>50)]
# Out:
# prasanna    30
# harika      40
# ammu        35
# teddy       45
# dtype: int64

# %%
s2["prasanna"]=90

# %%
s2
# Out:
# prasanna     90
# harika       40
# harshitha    65
# spandana     85
# ammu         35
# teddy        45
# srivani      78
# dtype: int64

# %%
#--------------Data frame------------------------------------


data = {
    "name": ["prasanna", "harika", "harshitha", "spandana", "teddy"],
    "age": [21, 20, 21, 18, np.nan],
    "department": ["IT", "FARMA", "IT", "MECH", "IT"],
    "salary": [50000, 20000, 50000, np.nan, 40000]
}
df=pd.DataFrame(data)
df
# Out:
#         name   age department   salary
# 0   prasanna  21.0         IT  50000.0
# 1     harika  20.0      FARMA  20000.0
# 2  harshitha  21.0         IT  50000.0
# 3   spandana  18.0       MECH      NaN
# 4      teddy   NaN         IT  40000.0

# %%
df.tail()
# Out:
#         name   age department   salary
# 0   prasanna  21.0         IT  50000.0
# 1     harika  20.0      FARMA  20000.0
# 2  harshitha  21.0         IT  50000.0
# 3   spandana  18.0       MECH      NaN
# 4      teddy   NaN         IT  40000.0

# %%
df.tail(2)
# Out:
#        name   age department   salary
# 3  spandana  18.0       MECH      NaN
# 4     teddy   NaN         IT  40000.0

# %%
df.head(2)
# Out:
#        name   age department   salary
# 0  prasanna  21.0         IT  50000.0
# 1    harika  20.0      FARMA  20000.0

# %%
df.loc[1,"age"]
# Out:
# 20.0

# %%
df.loc[0, "age"]
# Out:
# 21.0

# %%
df["age"]=df["age"]+5
df
# Out:
#         name   age department   salary
# 0   prasanna  31.0         IT  50000.0
# 1     harika  30.0      FARMA  20000.0
# 2  harshitha  31.0         IT  50000.0
# 3   spandana  28.0       MECH      NaN
# 4      teddy   NaN         IT  40000.0

# %%
df.["department"].value_counts()
# Out:
#   File "C:\Users\prasa\AppData\Local\Temp\ipykernel_116624\1300905969.py", line 1
#     df.["department"].value_counts()
#        ^
# SyntaxError: invalid syntax
